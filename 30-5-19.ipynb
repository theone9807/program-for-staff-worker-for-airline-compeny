# %% [raw]
# # Your program will be used by the staff who work for an airline company, e.g. Qantas Airways.
# The airline has a range of flights between various cities each day. Customers can book to fly on a
# flight, and if circumstances change they can cancel their booking at a later time, but not when it is
# less than 2 hours until the flight. The client want you to make a program that can be used to store
# the booking information, and the check-in information of the people on a flight.
# The program should allow staff to:
#
# 1. Create customer details – Name, Address, 3 digit passenger code that does not start with
#     zeros (e.g. 100 is the smallest acceptable value), whether the customer can only eat halal
#     meat (e.g. Muslim passengers)
# 2. Customers should be able to book seats on a flight, only one seat on a flight per customer.
#     They may however book a seat on a different flight.
# 3. Cancel a booking – only permitted 2 hours before the flight
# 4. Summary Information
#     a. The source and destination places.
#     b. The number of seats that are booked.
#     c. The number of seats that are available.
#     d. The number of passengers booked on the flight that need a halal meal.
# 5. Customer and flight information must persist
#
#
# Advanced Tasks
#
# 1. Create a new flight
# 2. Full validation of all input
# 3. Ask user to choose file name and path to save the file (Assumption is that the directory/folder already exists)
# 4. Report on a customer’s booking

# %%
import random

# %%
#Question 1

#number of seat available
N = 100
#food type count
fc = 0
while True:
    print('WELCOME to abc Airways! ')
    print('------------------------')
    print('Enter the asked questions for Sucessful Booking!')
    name = input('Enter name: ')
    add = input('Enter Address: ')
    try:
        code = int(input('Enter code greater than equal to 100: '))
    except:
        print('Inter integer  value greater than equal to 100!!')
        continue
    food = input('Do you eat only Halal Meat [y/n]:  ')
   
    if food.lower() == 'y':
        fc += 1
    else:
        pass


    #2 seat booking
    seat = input('Do you want to book a Seat[y/n]: ')
    
    if seat.lower() == 'y':
        print('Science You can book only 1 Seat in a flight! ')
        s = input('Enter yes[y] to book 1 seat: ')
        if s.lower() == 'y' or s.lower() == 'yes':
            source = input('Source place?: ')
            dest =input('Destinaton place?: ')

            print(f'Congrates {name} 1 seat has been sucessfully Booked! ')
            #seat no
            no = random.randint(1, 101)
            print('Your seat number is: ', no)
            N -= 1
            ask = input('Do you want to book more tickets [y/n]: ')
            if ask.lower() == 'y':
                continue
            else:
                break
    else:
        print('OKEY Bye!!!')
        break
    
    

#3 cancle booking
c = input('Do you want to cancle a booking [y/n]: ')
print('Note: Cancel bookig only permitted 2 hours before the flight!')
if c.lower() == 'y' or c.lower() == 'yes':
    print(f'Hey {name} your booking has been cancled!')
    no = 0
else:
    pass
# Out:
# WELCOME to abc Airways!
# ------------------------
# Enter the asked questions for Sucessful Booking!
# Enter name: h
# Enter Address: j
# Enter code greater than equal to 100: 777
# Do you eat only Halal Meat [y/n]:  y
# Do you want to book a Seat[y/n]: y
# Science You can book only 1 Seat in a flight!
# Enter yes[y] to book 1 seat: y
# Source place?: g
# Destinaton place?: h
# Congrates h 1 seat has been sucessfully Booked!
# Your seat number is:  66
# Do you want to book more tickets [y/n]: y
# WELCOME to abc Airways!
# ------------------------
# Enter the asked questions for Sucessful Booking!
# Enter name: u
# Enter Address: j
# Enter code greater than equal to 100: 777
# Do you eat only Halal Meat [y/n]:  y
# Do you want to book a Seat[y/n]: y
# Science You can book only 1 Seat in a flight!
# Enter yes[y] to book 1 seat: y
# Source place?: h
# Destinaton place?: o
# Congrates u 1 seat has been sucessfully Booked!
# Your seat number is:  89
# ...

# %%
#4 Summery

print('Summery Information')
print('Source: ',source)
print('Destination: ',dest)
print('Number of seats booked: ',(100 - N))
print('Number of passenger that eats only halal meat: ',fc)

#5
#Customer and flight information is persist
# Out:
# Summery Information
# Source:  h
# Destination:  o
# Number of seats booked:  2
# Number of passenger that eats only halal meat:  2

# %%
#advance task

# %%
#Question 1

#number of seat available
N = 100
#food type count
fc = 0
while True:
    print('WELCOME to abc Airways! ')
    print('------------------------')
    print('Enter the asked questions for Sucessful Booking!')
    name = input('Enter name: ')
    add = input('Enter Address: ')
    try:
        code = int(input('Enter code greater than equal to 100: '))
    except:
        print('Inter integer  value greater than equal to 100!!')
        continue
    food = input('Do you eat only Halal Meat [y/n]:  ')
   
    if food.lower() == 'y':
        fc += 1
    else:
        pass


    #2 seat booking
    seat = input('Do you want to book a Seat[y/n]: ')
    
    if seat.lower() == 'y':
        print('Science You can book only 1 Seat in a flight! ')
        s = input('Enter yes[y] to book 1 seat: ')
        if s.lower() == 'y' or s.lower() == 'yes':
            source = input('Source place?: ')
            dest =input('Destinaton place?: ')

            print(f'Congrates {name} 1 seat has been sucessfully Booked! ')
            #seat no
            no = random.randint(1, 101)
            print('Your seat number is: ', no)
            N -= 1
            ask = input('Do you want to book more tickets [y/n]: ')
            if ask.lower() == 'y':
                continue
            else:
                break
    else:
        print('OKEY Bye!!!')
        break
    
    
    
#ask to save
q = input('Do you want to save the details file [y/n]: ')
if q.lower() == 'y':
    dict = {'Source: ': source, 'Destination: ' : dest, 'Number of seats booked: ':(100 - N),'Number of passenger that eats only halal meat: ': fc }
    
    
    q2 = input('Enter the file name to save: ')
    print(f'File is saved at the path to which python is running with name {q2}')
    f = open(f"{q2}.txt","w")
    f.write( str(dict) )
    f.close()

else: pass
# Out:
# WELCOME to abc Airways!
# ------------------------
# Enter the asked questions for Sucessful Booking!
# Enter name: a
# Enter Address: a
# Enter code greater than equal to 100: 111
# Do you eat only Halal Meat [y/n]:  y
# Do you want to book a Seat[y/n]: y
# Science You can book only 1 Seat in a flight!
# Enter yes[y] to book 1 seat: y
# Source place?: y
# Destinaton place?: y
# Congrates a 1 seat has been sucessfully Booked!
# Your seat number is:  64
# Do you want to book more tickets [y/n]: n
# Do you want to save the details file [y/n]: y
# Enter the file name to save: abc
# File is saved at the path to which python is running with name abc
